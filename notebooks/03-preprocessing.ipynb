# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
X, y =load_iris(return_X_y=True)
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size=0.2)
scale = StandardScaler()
X_train_scaled = scale.fit_transform(X_train)
X_test_scaled = scale.transform(X_test)
X_train_scaled
# Out:
# array([[ 1.51624468,  0.12937927,  0.65376517,  0.42159912],
#        [-0.03887807, -0.7331492 ,  0.88248768,  1.81148634],
#        [ 2.29380605, -0.30188496,  1.74019708,  1.39452017],
#        [-0.16847163, -1.16441344, -0.03240236, -0.13435576],
#        [-1.20522013, -0.08625285, -1.17601489, -1.38525426],
#        [ 0.22030906, -0.51751708,  0.53940391,  0.56058784],
#        [-1.59400082,  0.99190774, -1.46191803, -1.24626554],
#        [ 0.47949618, -0.7331492 ,  0.7109458 ,  0.97755401],
#        [-0.94603301,  1.42317198, -1.11883427, -1.24626554],
#        [-0.16847163,  2.71696468, -1.17601489, -0.96828809],
#        [-1.07562657,  0.77627562, -1.29037615, -1.10727682],
#        [-0.03887807, -0.94878132,  0.19632015,  0.14362168],
#        [-0.16847163, -0.30188496,  0.36786203,  0.14362168],
#        [-1.07562657,  0.34501139, -1.23319552, -1.24626554],
#        [-0.03887807, -0.94878132,  0.88248768,  1.11654273],
#        [-1.20522013, -0.30188496, -1.23319552, -1.24626554],
#        [-0.03887807, -1.16441344,  0.25350078,  0.14362168],
#        [ 1.25705755, -0.7331492 ,  0.7109458 ,  0.42159912],
#        [-1.20522013, -1.38004555,  0.53940391,  0.83856529],
#        [-0.94603301,  0.56064351, -1.17601489, -1.24626554],
#        [-0.16847163,  1.42317198, -1.06165364, -1.10727682],
#        [ 0.09071549, -0.30188496,  0.88248768,  0.97755401],
#        [-0.03887807, -0.94878132,  0.31068141, -0.13435576],
#        [ 2.42339962,  1.42317198,  1.79737771,  1.53350889],
#        [ 0.73868331, -0.51751708,  0.42504266,  0.2826104 ],
#        [ 0.34990262, -0.51751708,  0.65376517,  0.42159912],
#        [-1.07562657,  0.77627562, -1.11883427, -0.69031065],
#        [ 0.86827687, -0.30188496,  1.28275207,  1.53350889],
#        [-0.03887807,  1.85443621, -1.34755678, -1.24626554],
#        [ 0.99787043, -0.51751708,  0.59658454,  0.2826104 ]])
